# %%
import pandas as pd
import numpy as np

# %%
DATA_PATH = "../data/raw/Sample - Superstore.xls"
df = pd.read_excel(DATA_PATH)

# %%
date_cols = ["Order Date", "Ship Date"]
for col in date_cols:
    df[col] = pd.to_datetime(df[col])

numeric_cols = ["Sales", "Profit", "Quantity", "Discount"]
df[numeric_cols] = df[numeric_cols].apply(pd.to_numeric)

# %%
from pathlib import Path

out_dir = Path("../data/processed")
out_dir.mkdir(parents=True, exist_ok=True)

df.to_csv(out_dir / "superstore_clean.csv", index=False)
print("Saved:", out_dir / "superstore_clean.csv", "rows:", len(df), "cols:", df.shape[1])
# Out:
# Saved: ../data/processed/superstore_clean.csv rows: 9994 cols: 21
