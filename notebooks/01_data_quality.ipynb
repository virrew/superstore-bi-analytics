# %% [markdown]
# # Data Quality & Exploration
#
# This notebook explores the raw Superstore dataset to understand
# data quality, structure, and potential issues before transformation.

# %% [markdown]
# import pandas as pd
# import numpy as np
#
# print("pandas:", pd.__version__)
